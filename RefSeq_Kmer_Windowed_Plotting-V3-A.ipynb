# %% [markdown]
# # Exploring the reference database
# Let's see what properties we can find :)

# %% [markdown]
# ## Structure
# In `genome/`, there's multiple sub-folder, we will start with `Bacteria`
# It then contains all recorded species/strands in individual folders

# %% [markdown]
# ## Content of each species/strand folder
# In each folder there's:
# - .ASN with
#  - `taxname "Acetobacter pasteurianus IFO 3283-32"`
#  - `db "taxon", tag id 634457`
#  - `genus "Acetobacter", species "pasteurianus"`
#  - `mod { {subtype strain, subname "IFO 3283" }, { subtype substrain, subname "IFO 3283-32" } },`
#  - `lineage "Bacteria; Proteobacteria; Alphaproteobacteria; Rhodospirillales; Acetobacteraceae; Acetobacter",`
# - .FAA
#  - with multiple ">gi|384064451|ref|YP_005479409.1| hypothetical protein APA32_44160 [Acetobacter pasteurianus IFO 3283-32]"
#  - and probably the amino-acid sequence for each of these proteins
# - .FFN
#  - multiple ">gi|384064450|ref|NC_017102.1|:c562-116 Acetobacter pasteurianus IFO 3283-32 plasmid pAPA32-040, complete sequence"
#  - probably DNA sequence
# - .FNA
#  - Also DNA
# - .GBK : Human readable format with most info !
#  - have an identifier `/db_xref="taxon:634457"`
# - .GFF with `##species http://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=634457`
# - .RPT
#  - seem good with simple Python INI config file format:
#    - `DNA  length = 3035`
#    - `Taxname: Acetobacter pasteurianus IFO 3283-32`
#    - `Taxid: 634457`

# %% [markdown]
# http://defindit.com/readme_files/ncbi_file_extension_format.html

# %% [raw]
# .asn	genome record in asn.1 format
# .faa	protein sequences in fasta format, text file
# .ffn	protein coding portions of the genome segments
# .fna	genome fasta sequence
# .frn	rna coding portions of the genome segments
# .gbk	genome in genbank file format
# .gff	genome features
# .ptt	protein table
# .rnt	rna table
# .rpt	summary report
# .val	binary file (genome project?)

# %% [markdown]
# What we need is the taxo id, name, and the DNA, which can be found in:
#  - .gbk for the taxo and name
#  - .fna for the sequence

# %% [markdown]
# #### File marker
# https://www.ncbi.nlm.nih.gov/books/NBK21091/table/ch18.T.refseq_accession_numbers_and_mole/?report=objectonly <br>
# `NC_	Genomic	Complete genomic molecule, usually reference assembly`
#
# #### Status
# https://www.ncbi.nlm.nih.gov/books/NBK21091/table/ch18.T.refseq_status_codes/?report=objectonly <br>
# in `COMMENT` : VALIDATED > REVIEWED > PROVISIONAL > ...

# %% [markdown]
# ## Coding
# ### Import and Paths

# %%
import os
import pandas as pd
import numpy as np
import configparser
import pickle
from Bio import SeqIO
from time import time
from tqdm import tqdm_notebook as tqdm

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
path_ref_db = "/mnt/genomeDB/ncbi/genomes/Bacteria/"
path_kmer_freq = "/home/sjriondet/Data/Kmer_frequencies/"

# %%
os.chdir(path_ref_db)

# %% [markdown]
# ## Functions

# %%
def normalise_counts(kmer_count):
    """Nested dict, normalize each of the sub dict. """
    for window in kmer_count.keys():
        max_val = max(kmer_count[window].values())
        for key in kmer_count[window]:
            kmer_count[window][key] /= max_val

# %% [markdown]
# ## Tests

# %%
path_4mer = "4_V3/"
path_4mer = os.path.join(path_kmer_freq, path_4mer)

# %%
names = []
files = []
counts = []
for f in os.scandir(path_4mer):
    if f.name.endswith(".pd"):
        with open(f, 'rb') as file:
            files.append(f.path)
            names.append(os.path.splitext(f.name)[0])
#             counts.append(pickle.load(file))099
print(f"{len(names)} files")
# Out:
# 20 files

# %%
df = pd.read_pickle(files[0])

# %%
df
# Out:
#                                             bacteria        fna  len_genome  \
# 0     Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017102        3204
# 1     Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017102        3204
# 2     Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017102        3204
# 3     Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017103        3035
# 4     Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017103        3035
# 5     Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017103        3035
# 6     Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 7     Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 8     Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 9     Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 10    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 11    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 12    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 13    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 14    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 15    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 16    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 17    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 18    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 19    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 20    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 21    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 22    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 23    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 24    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 25    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 26    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 27    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 28    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 29    Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# ...                                              ...        ...         ...
# 3303  Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017149      182940
# 3330  179000     5     2     2     5     1     3  ...     4     8     5     6
# 3331  180000     1     1     1     0     5     4  ...     7     5     5     3
# 3332  181000     1     2     5     4     3     5  ...    10     3     1     4
#
#       TTGG  TTGT  TTTA  TTTC  TTTG  TTTT
# 0        8     6     6    13     8    14
# 1        2     1     1     3     2     1
# 2        2     3     3     2     3     0
# 3        4     5     1     9     7    10
# 4        0     1     2     3     3     9
# 5        2     3     1     3     2     1
# 6        6     3     2     9     3     6
# 7        9     7     3    13    14    10
# 8        6     1     4     8     4     8
# 9        1     6     7     3     8    21
# 10      17     5     6     6    19    25
# 11       9     6     2     8     7     8
# 12       4     0     1    13     3     9
# 13       1     2     4    11     4    11
# 14       5     5     5    12     3     6
# 15       7     7     2     9     8     2
# 16       8     8     3     8     7     6
# 17       3     2     5     4     5     5
# 18       6     7     7     8     6     9
# 19       3     8     8    10    10    23
# 20       6     6     6     7     9     8
# 21       5     7     4     9    10    14
# 22       9     4     5     3     8     8
# 23       9     3     2     7     4     7
# 24       1     6     3     9     5    10
# 25      10     2     1     5     4     3
# 26       9     2     0     5     7     3
# 27      10     3     1    10     6    10
# 28       9     2     1    13     6    14
# 29       5     3     6     8     5    13
# ...    ...   ...   ...   ...   ...   ...
# 3303     1     3     1     2     7     6
# 3304     0     2     1     0     1     0
# 3305     4     5     4     3     3     5
# 3306     4     7     1     5     9     4
# 3307     4     3     1     3     2     0
# 3308     1     2     0     4     3     1
# 3309     2     4     1     2     2     5
# 3310     3     1     3    10     1     4
# 3311     1     3     0     5     0     0
# 3312     3     0     3     8     1     5
# 3313     5     3     0     9     1     8
# 3314     4     2     0    13     3    11
# 3315     7     2     2     4     0     0
# 3316     5     2     0     8     5     4
# 3317     4     4     1    12     0     6
# 3318     3     2     1     3     3     2
# 3319     3     1     6     5     3     8
# 3320     6     5     6     7     3    14
# 3321     1     5     3     7     5    10
# 3322     5     6     8    10     7     9
# 3323     5     6    13     8    10    16
# 3324     4     5     3     6     7     9
# 3325     4     4     0     8     5     3
# 3326     5     0     3     3     4     4
# 3327     6     3     3     7     5     6
# 3328     5     6     6     3     6     6
# 3329     2     2     3     7     4    11
# 3330     4     5     0     7     6     5
# 3331     3     4     1     5     5     2
# 3332     2     7     1     5     5    10
#
# [3333 rows x 260 columns]

# %%
kmers_list = df.columns.to_list()[4:]

# %%
cols_spe = sorted(list(set(df.columns.to_list()).difference(set(kmers_list))))

# %%
cols_spe
# Out:
# ['bacteria', 'fna', 'len_genome', 'start']

# %%
df_concat = []
for file in files:
    df_concat.append(pd.read_pickle(file))

# %%
all_df = pd.concat(df_concat)

# %%
all_df.bacteria = all_df.bacteria.astype("category")
all_df.fna = all_df.fna.astype("category")

# %%
all_df.sample(5)
# Out:
#                                             bacteria        fna  len_genome  \
# 3482         Acetobacterium_woodii_DSM_1030_uid88073  NC_016894     4044777
# 246   Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 1860  Acetobacter_pasteurianus_IFO_3283_12_uid158379  NC_017108     2904624
# 2860   Acetobacter_pasteurianus_IFO_3283_01_uid59279  NC_013209     2907495
# 2472         Acetobacterium_woodii_DSM_1030_uid88073  NC_016894     4044777
#
#         start  AAAA  AAAC  AAAG  AAAT  AACA  AACC  ...  TTCG  TTCT  TTGA  \
# 3482  3482000    10     6     6     9     7     7  ...     8     5     3
# 246    240000     6     4     8     4     5     3  ...     1     6     0
# 1860  1860000     5     5     6     6     7     7  ...     2     2     0
# 2860  2860000     8     3     3     2     7     1  ...     0     7     7
# 2472  2472000    17     9     4    14     6     4  ...     1     9     7
#
#       TTGC  TTGG  TTGT  TTTA  TTTC  TTTG  TTTT
# 3482     6     3     4     5     8     6     8
# 246      9     4     5     1     7     4     0
# 1860     7     3     3     4     1     6     5
# 2860     6     4     2     5     9     5     7
# 2472     6     2     3    18    13    11    24
#
# [5 rows x 260 columns]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
len(kmers_list)
# Out:
# 256

# %%
pca = PCA(n_components=50)
pca.fit(all_df[kmers_list])
# Out:
# PCA(copy=True, iterated_power='auto', n_components=50, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
plt.scatter(x=range(len(pca.explained_variance_ratio_)+1), 
            y=np.insert(pca.explained_variance_ratio_.cumsum(), 0, 0))
# plt.plot(pca.explained_variance_ratio_)
plt.show()
print(f"captured by PCA: {sum(pca.explained_variance_ratio_)*100:0.1f}%")
# Out:
# captured by PCA: 78.9%

# %%
pca_n = 10

# %%
pca = PCA(n_components=pca_n)
pca.fit(all_df[kmers_list])
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
np_pca = pca.transform(all_df[kmers_list])

# %%
cols_pca = [f"pca_{i+1}" for i in range(pca_n)]

# %%
df_pca = pd.DataFrame(np_pca, columns=cols_pca)

# %%
df_pca = pd.concat([all_df[cols_spe].reset_index(inplace=False, drop=True), df_pca], axis=1) # , ignore_index=True)

# %%
df_pca
# Out:
#                                              bacteria        fna  len_genome  \
# 0      Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017102        3204
# 1      Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017102        3204
# 2      Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017102        3204
# 3      Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017103        3035
# 4      Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017103        3035
# 5      Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017103        3035
# 6      Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 7      Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 8      Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 9      Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 10     Acetobacter_pasteurianus_IFO_3283_32_uid158375  NC_017111     2904642
# 75390  -5.082042  -2.352181   1.935853   2.874236  -1.298472         19
# 75391   3.093176  -6.117447   1.774294   3.349414   1.402384         19
# 75392  -2.894671  -8.326866   3.348356   4.648926   7.906982         19
# 75393   1.218207  -7.785191   5.661891   2.174495   5.057776         19
# 75394   8.858615  -5.358384  -0.063296  -1.512141   7.417018         19
# 75395  11.440397 -10.745158   5.920130   3.704708   5.354272         19
# 75396  -1.881862  -7.175272   1.413715   5.261026   7.430815         19
# 75397  -7.211379  -5.403639  -1.207590  -3.960393   8.072481         19
# 75398   1.490701 -10.280103   3.590019   1.655956  14.954366         19
# 75399   2.805374 -10.218297   8.946586   4.208911   5.173226         19
# 75400  10.994998  -2.461250   5.217526  -5.389412  12.432869         19
# 75401   1.583256  -4.654866   2.921687  -5.322330   4.400478         19
# 75402   0.309849  -6.569784   4.030878   1.368504   5.905497         19
# 75403   9.155047 -10.163974   8.437532   0.530252   8.353583         19
# 75404  10.392213  -6.151402   5.060505  -1.847157  12.546631         19
# 75405   8.684063  -7.378247   1.232597  -0.614563  12.641550         19
# 75406   1.782647 -11.032484   5.554886   3.132354   0.622761         19
# 75407  20.688408  -6.242013   8.992541   9.391025  18.051162         19
# 75408  -8.061793 -13.223600   6.334079  -2.928249   3.445505         19
# 75409   5.720627 -11.398663   3.349274  -3.120101   7.916325         19
# 75410   6.133431  -8.462465   5.151003   2.561444   1.992049         19
# 75411   6.457596  -9.290950  -0.752293   4.267020   0.779727         19
# 75412   0.472897 -13.396619   2.644300  -4.833417   0.799066         19
# 75413  -8.802118  -1.093735   7.418740  -8.594228   3.265500         19
# 75414 -21.780514  -8.787406   0.925670  -8.758687   6.479478         19
# 75415 -17.826693  -7.441059   8.607323  -1.177362   2.940834         19
# 75416   4.173118 -14.686715   2.705457   5.293374   5.259664         19
# 75417   0.158286  -3.783256   6.088828   5.309099   1.565904         19
#
# [75418 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 13, 8

# %%
df_pca.sample(1000).plot.scatter(x="pca_1", y="pca_2", s=1, c="color_map", colormap="nipy_spectral")  # gist_ncar
plt.show()
print(f"captured by PCA: {sum(pca.explained_variance_ratio_[:2])*100:0.1f}%")
# Out:
# captured by PCA: 40.8%

# %% [markdown]
# ## Machine Learning classification

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler, scale

# %%
from sklearn import linear_model
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import ElasticNet
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
df_pca1000 = df_pca.sample(10000, random_state=0)

# %%
X_train, X_test, y_train, y_test = train_test_split(scale(df_pca1000[cols_pca]), df_pca1000.bacteria.to_list(), test_size=0.1, random_state=0)

# %%
df_pca.sample(5)
# Out:
#                                               bacteria        fna  len_genome  \
# 38104           Achromobacter_xylosoxidans_A8_uid59899  NC_014640     7013095
# 11177          Acetobacterium_woodii_DSM_1030_uid88073  NC_016894     4044777
# 63372   Acetobacter_pasteurianus_IFO_3283_07_uid158381  NC_017121     2906044
# 56768          Acaryochloris_marina_MBIC11017_uid58167  NC_009925     6503724
# 18307  Achromobacter_xylosoxidans_NBRC_15126_uid232243  NC_023061     6683584
#
#          start      pca_1      pca_2      pca_3      pca_4      pca_5  \
# 38104  5415000  39.021009   4.252767  -3.971797  -2.991652  -3.302860
# 11177  4019000 -36.008729  12.597204 -10.355042  -7.169450  12.261810
# 63372  1669000  -6.981006 -16.290613  -4.727470 -10.673960  17.188189
# 56768  3472000 -22.338535  -0.457360  -0.910466   8.200914   3.614186
# 18307   713000  59.286254  17.582359   9.942921  -1.077894  16.741498
#
#            pca_6      pca_7     pca_8     pca_9    pca_10  color_map
# 38104  -4.409731   5.235342  1.028774  5.594871  5.823225          9
# 11177  12.862301 -20.601201  8.607170  0.775104  2.402034          3
# 63372  -2.628318   0.104269 -8.519003 -2.903814  2.345525         15
# 56768   3.167972   1.680281 -1.809877 -0.617131 -6.022005         14
# 18307  -4.169867  -4.667401  3.138580 -4.313125  1.020105          6

# %% [raw]
# y_test

# %% [raw]
# names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
#          "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
#          "Naive Bayes", "QDA"]
#
# classifiers = [
#     KNeighborsClassifier(3),
#     SVC(kernel="linear", C=0.025),
#     SVC(gamma=2, C=1),
#     GaussianProcessClassifier(1.0 * RBF(1.0)),
#     DecisionTreeClassifier(max_depth=5),
#     RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
#     MLPClassifier(alpha=1),
#     AdaBoostClassifier(),
#     GaussianNB(),
#     QuadraticDiscriminantAnalysis()]

# %%
models = {
    "RF": RandomForestClassifier(max_depth=20, random_state=0, n_estimators=100, n_jobs=6),
    "SVM_lin": SVC(kernel="linear", C=0.025),
    "SVM_rbf": SVC(kernel='rbf', C=1, gamma='auto', cache_size=1000),
    "KNeigh": KNeighborsClassifier(n_neighbors=20, n_jobs=6),
    "DTree": DecisionTreeClassifier(max_depth=20),
    "NNet": MLPClassifier(alpha=1),
    "AdaBoost": AdaBoostClassifier(),
    "Naive_Bayes": GaussianNB(),
    "QDA": QuadraticDiscriminantAnalysis()
}

# %%
results = {}

# %%
for name in tqdm(models.keys()):
    if name not in results.keys():
        print(name)
        start = time()
        models[name].fit(X_train, y_train)
        score = models[name].score(X_test, y_test)
        predicted = models[name].predict(X_test)
        
        results[name] = {}
        results[name]["time"] = time() - start
        results[name]["score"] = score
        results[name]["predicted"] = predicted
# Out:
# RF
# SVM_lin
# SVM_rbf
# KNeigh
# DTree
# NNet
# AdaBoost
# Naive_Bayes
# QDA

# %% [raw]
# results

# %%
to_df = {"Ground_Truth": y_test}
for name in results.keys():
    predicted = results[name]["predicted"]
    to_df[f"{name}"] = (y_test==predicted).astype(int)
    to_df[f"{name}_pred"] = predicted
pd_res = pd.DataFrame(to_df)

# %%
ranking = 100 * pd_res.sum(numeric_only=True) / pd_res.RF.count()

# %%
ranking
# Out:
# RF            42.20
# SVM_lin       43.00
# SVM_rbf       44.90
# KNeigh        45.00
# DTree         37.70
# NNet          44.30
# AdaBoost      26.00
# Naive_Bayes   43.20
# QDA           42.90
# dtype: float64

# %%
pd_ranking = pd.DataFrame({"name": ranking.index.values, 
                           "percentage": ranking.values})

# %%
pd_ranking["time"] = 0
for name in results.keys():
    pd_ranking.loc[pd_ranking["name"] == name, ['time']] = results[name]["time"]

# %%
pd_ranking.sort_values(by=["percentage"], ascending=False)
# Out:
#           name  percentage  time
# 3       KNeigh       45.00  0.48
# 2      SVM_rbf       44.90  4.06
# 5         NNet       44.30  9.85
# 7  Naive_Bayes       43.20  0.03
# 1      SVM_lin       43.00  1.93
# 8          QDA       42.90  0.03
# 0           RF       42.20  1.00
# 4        DTree       37.70  0.21
# 6     AdaBoost       26.00  2.24

# %%
pd_res
# Out:
#                                           Ground_Truth  RF_gotit  \
# 0       Acetobacter_pasteurianus_IFO_3283_22_uid158383         0
# 1              Acaryochloris_marina_MBIC11017_uid58167         1
# 2                 Achromobacter_xylosoxidans_uid205255         1
# 3               Achromobacter_xylosoxidans_A8_uid59899         1
# 4              Acaryochloris_marina_MBIC11017_uid58167         1
# 5                 Achromobacter_xylosoxidans_uid205255         0
# 6      Achromobacter_xylosoxidans_NBRC_15126_uid232243         0
# 7       Acetobacter_pasteurianus_IFO_3283_03_uid158373         0
# 8                 Achromobacter_xylosoxidans_uid205255         1
# 9       Acetobacter_pasteurianus_IFO_3283_32_uid158375         0
# 10          Acetohalobium_arabaticum_DSM_5501_uid51423         1
# 11               Acholeplasma_laidlawii_PG_8A_uid58901         1
# 12                Achromobacter_xylosoxidans_uid205255         0
# 13     Achromobacter_xylosoxidans_NBRC_15126_uid232243         1
# 14      Acetobacter_pasteurianus_IFO_3283_32_uid158375         0
# 15       Acetobacter_pasteurianus_IFO_3283_01_uid59279         0
# 16             Acetobacterium_woodii_DSM_1030_uid88073         1
# 17      Acetobacter_pasteurianus_IFO_3283_07_uid158381         0
# 18              Achromobacter_xylosoxidans_A8_uid59899         1
# 19       Acetobacter_pasteurianus_IFO_3283_01_uid59279         0
# 20      Acetobacter_pasteurianus_IFO_3283_07_uid158381         0
# 21   Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...         0
# 22           Acidilobus_saccharovorans_345_15_uid51395         0
# 23                Achromobacter_xylosoxidans_uid205255         0
# 24      Acetobacter_pasteurianus_IFO_3283_26_uid158531         0
# 25      Acetobacter_pasteurianus_IFO_3283_32_uid158375         0
# 26      Acetobacter_pasteurianus_IFO_3283_32_uid158375         0
# 27      Acetobacter_pasteurianus_IFO_3283_07_uid158381         1
# 28              Achromobacter_xylosoxidans_A8_uid59899         1
# 29      Acetobacter_pasteurianus_IFO_3283_32_uid158375         0
# ..                                                 ...       ...
# 970    Achromobacter_xylosoxidans_NBRC_15126_uid232243         0
# 971             Achromobacter_xylosoxidans_A8_uid59899         0
# 972            Acaryochloris_marina_MBIC11017_uid58167         1
# 973     Acetobacter_pasteurianus_IFO_3283_03_uid158373         0
# 974     Acetobacter_pasteurianus_IFO_3283_32_uid158375         0
# 975     Acetobacter_pasteurianus_IFO_3283_26_uid158531         1
# 976               Achromobacter_xylosoxidans_uid205255         0
# 977  Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...         0
# 978     Acetobacter_pasteurianus_IFO_3283_22_uid158383         0
# 979        Acidaminococcus_intestini_RyC_MR95_uid74445         0
# 980            Acaryochloris_marina_MBIC11017_uid58167         1
# 981  Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...         0
# 982            Acaryochloris_marina_MBIC11017_uid58167         1
# 983             Achromobacter_xylosoxidans_A8_uid59899         0
# 984    Achromobacter_xylosoxidans_NBRC_15126_uid232243         1
# 985             Achromobacter_xylosoxidans_A8_uid59899         0
# 986            Acetobacterium_woodii_DSM_1030_uid88073         1
# 987      Acetobacter_pasteurianus_IFO_3283_01_uid59279         0
# 988     Acetobacter_pasteurianus_IFO_3283_12_uid158379         0
# 989             Achromobacter_xylosoxidans_A8_uid59899         1
# 990     Acetobacter_pasteurianus_IFO_3283_07_uid158381         0
# 991               Achromobacter_xylosoxidans_uid205255         1
# 992     Acetobacter_pasteurianus_IFO_3283_26_uid158531         0
# 993            Acetobacter_pasteurianus_386B_uid214433         0
# 994     Acetobacter_pasteurianus_IFO_3283_03_uid158373         0
# 995             Achromobacter_xylosoxidans_A8_uid59899         1
# 996      Acetobacter_pasteurianus_IFO_3283_01_uid59279         0
# 997             Achromobacter_xylosoxidans_A8_uid59899         0
# 998     Acetobacter_pasteurianus_IFO_3283_07_uid158381         0
# 999     Acetobacter_pasteurianus_IFO_3283_26_uid158531         0
#
#                                                RF_pred  SVM_lin_gotit  \
# 0        Acetobacter_pasteurianus_IFO_3283_01_uid59279              0
# 1              Acaryochloris_marina_MBIC11017_uid58167              1
# 2                 Achromobacter_xylosoxidans_uid205255              1
# 3               Achromobacter_xylosoxidans_A8_uid59899              1
# 4              Acaryochloris_marina_MBIC11017_uid58167              1
# 5               Achromobacter_xylosoxidans_A8_uid59899              0
# 6                 Achromobacter_xylosoxidans_uid205255              1
# 7       Acetobacter_pasteurianus_IFO_3283_22_uid158383              0
# 8                 Achromobacter_xylosoxidans_uid205255              0
# 9              Acaryochloris_marina_MBIC11017_uid58167              0
# 10          Acetohalobium_arabaticum_DSM_5501_uid51423              1
# 11               Acholeplasma_laidlawii_PG_8A_uid58901              1
# 12              Achromobacter_xylosoxidans_A8_uid59899              0
# 13     Achromobacter_xylosoxidans_NBRC_15126_uid232243              1
# 14      Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 15      Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 16             Acetobacterium_woodii_DSM_1030_uid88073              1
# 17      Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 18              Achromobacter_xylosoxidans_A8_uid59899              0
# 19   Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...              0
# 20      Acetobacter_pasteurianus_IFO_3283_26_uid158531              0
# 21      Acetobacter_pasteurianus_IFO_3283_32_uid158375              0
# 22          Acetohalobium_arabaticum_DSM_5501_uid51423              0
# 23     Achromobacter_xylosoxidans_NBRC_15126_uid232243              1
# 24      Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 25      Acetobacter_pasteurianus_IFO_3283_22_uid158383              0
# 26      Acetobacter_pasteurianus_IFO_3283_26_uid158531              0
# 27      Acetobacter_pasteurianus_IFO_3283_07_uid158381              0
# 28              Achromobacter_xylosoxidans_A8_uid59899              1
# 29              Achromobacter_xylosoxidans_A8_uid59899              0
# ..                                                 ...            ...
# 970               Achromobacter_xylosoxidans_uid205255              1
# 971               Achromobacter_xylosoxidans_uid205255              1
# 972            Acaryochloris_marina_MBIC11017_uid58167              1
# 973     Acetobacter_pasteurianus_IFO_3283_26_uid158531              0
# 974  Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...              0
# 975     Acetobacter_pasteurianus_IFO_3283_26_uid158531              0
# 976             Achromobacter_xylosoxidans_A8_uid59899              0
# 977     Acetobacter_pasteurianus_IFO_3283_22_uid158383              0
# 978  Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...              0
# 979            Acaryochloris_marina_MBIC11017_uid58167              1
# 980            Acaryochloris_marina_MBIC11017_uid58167              1
# 981      Acetobacter_pasteurianus_IFO_3283_01_uid59279              0
# 982            Acaryochloris_marina_MBIC11017_uid58167              1
# 983               Achromobacter_xylosoxidans_uid205255              0
# 984    Achromobacter_xylosoxidans_NBRC_15126_uid232243              1
# 985               Achromobacter_xylosoxidans_uid205255              1
# 986            Acetobacterium_woodii_DSM_1030_uid88073              1
# 987     Acetobacter_pasteurianus_IFO_3283_22_uid158383              0
# 988     Acetobacter_pasteurianus_IFO_3283_26_uid158531              0
# 989             Achromobacter_xylosoxidans_A8_uid59899              1
# 990     Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 991               Achromobacter_xylosoxidans_uid205255              0
# 992            Acetobacter_pasteurianus_386B_uid214433              0
# 993  Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...              0
# 994     Acetobacter_pasteurianus_IFO_3283_22_uid158383              0
# 995             Achromobacter_xylosoxidans_A8_uid59899              1
# 996            Acetobacter_pasteurianus_386B_uid214433              0
# 997    Achromobacter_xylosoxidans_NBRC_15126_uid232243              0
# 998      Acetobacter_pasteurianus_IFO_3283_01_uid59279              0
# 999      Acetobacter_pasteurianus_IFO_3283_01_uid59279              0
#
#                                         SVM_lin_pred  SVM_rbf_gotit  \
# 0     Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 1            Acaryochloris_marina_MBIC11017_uid58167              1
# 2               Achromobacter_xylosoxidans_uid205255              1
# 3             Achromobacter_xylosoxidans_A8_uid59899              1
# 4            Acaryochloris_marina_MBIC11017_uid58167              1
# 5             Achromobacter_xylosoxidans_A8_uid59899              0
# 6    Achromobacter_xylosoxidans_NBRC_15126_uid232243              1
# 7     Acetobacter_pasteurianus_IFO_3283_32_uid158375              0
# 8             Achromobacter_xylosoxidans_A8_uid59899              0
# 9            Acaryochloris_marina_MBIC11017_uid58167              0
# 10        Acetohalobium_arabaticum_DSM_5501_uid51423              1
# 11             Acholeplasma_laidlawii_PG_8A_uid58901              1
# 12            Achromobacter_xylosoxidans_A8_uid59899              0
# 13   Achromobacter_xylosoxidans_NBRC_15126_uid232243              1
# 14    Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 15    Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 16           Acetobacterium_woodii_DSM_1030_uid88073              1
# 17    Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 18              Achromobacter_xylosoxidans_uid205255              1
# 19    Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 20    Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 21    Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 22        Acetohalobium_arabaticum_DSM_5501_uid51423              0
# 23              Achromobacter_xylosoxidans_uid205255              1
# 24    Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 25    Acetobacter_pasteurianus_IFO_3283_26_uid158531              0
# 26    Acetobacter_pasteurianus_IFO_3283_26_uid158531              0
# 27    Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 28            Achromobacter_xylosoxidans_A8_uid59899              0
# 29           Acaryochloris_marina_MBIC11017_uid58167              0
# ..                                               ...            ...
# 970  Achromobacter_xylosoxidans_NBRC_15126_uid232243              0
# 971           Achromobacter_xylosoxidans_A8_uid59899              1
# 972          Acaryochloris_marina_MBIC11017_uid58167              1
# 973   Acetobacter_pasteurianus_IFO_3283_07_uid158381              0
# 974   Acetobacter_pasteurianus_IFO_3283_07_uid158381              0
# 975   Acetobacter_pasteurianus_IFO_3283_32_uid158375              0
# 976  Achromobacter_xylosoxidans_NBRC_15126_uid232243              1
# 977   Acetobacter_pasteurianus_IFO_3283_26_uid158531              0
# 978   Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 979      Acidaminococcus_intestini_RyC_MR95_uid74445              1
# 980          Acaryochloris_marina_MBIC11017_uid58167              1
# 981   Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 982          Acaryochloris_marina_MBIC11017_uid58167              1
# 983             Achromobacter_xylosoxidans_uid205255              1
# 984  Achromobacter_xylosoxidans_NBRC_15126_uid232243              0
# 985           Achromobacter_xylosoxidans_A8_uid59899              1
# 986          Acetobacterium_woodii_DSM_1030_uid88073              1
# 987   Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 988   Acetobacter_pasteurianus_IFO_3283_26_uid158531              0
# 989           Achromobacter_xylosoxidans_A8_uid59899              1
# 990   Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 991  Achromobacter_xylosoxidans_NBRC_15126_uid232243              0
# 992    Acetobacter_pasteurianus_IFO_3283_01_uid59279              0
# 993   Acetobacter_pasteurianus_IFO_3283_26_uid158531              0
# 994   Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 995           Achromobacter_xylosoxidans_A8_uid59899              1
# 996   Acetobacter_pasteurianus_IFO_3283_26_uid158531              0
# 997  Achromobacter_xylosoxidans_NBRC_15126_uid232243              0
# 998   Acetobacter_pasteurianus_IFO_3283_12_uid158379              0
# 999    Acetobacter_pasteurianus_IFO_3283_01_uid59279              0
#
#                                           SVM_rbf_pred  DTree_gotit  \
# 0        Acetobacter_pasteurianus_IFO_3283_01_uid59279            0
# 1              Acaryochloris_marina_MBIC11017_uid58167            1
# 2                 Achromobacter_xylosoxidans_uid205255            1
# 3               Achromobacter_xylosoxidans_A8_uid59899            1
# 4              Acaryochloris_marina_MBIC11017_uid58167            0
# 5               Achromobacter_xylosoxidans_A8_uid59899            1
# 6      Achromobacter_xylosoxidans_NBRC_15126_uid232243            0
# 7       Acetobacter_pasteurianus_IFO_3283_32_uid158375            0
# 8               Achromobacter_xylosoxidans_A8_uid59899            1
# 9              Acaryochloris_marina_MBIC11017_uid58167            0
# 10          Acetohalobium_arabaticum_DSM_5501_uid51423            1
# 11               Acholeplasma_laidlawii_PG_8A_uid58901            1
# 12              Achromobacter_xylosoxidans_A8_uid59899            0
# 13     Achromobacter_xylosoxidans_NBRC_15126_uid232243            0
# 14      Acetobacter_pasteurianus_IFO_3283_12_uid158379            0
# 15      Acetobacter_pasteurianus_IFO_3283_26_uid158531            0
# 16             Acetobacterium_woodii_DSM_1030_uid88073            0
# 17      Acetobacter_pasteurianus_IFO_3283_12_uid158379            0
# 18              Achromobacter_xylosoxidans_A8_uid59899            0
# 19      Acetobacter_pasteurianus_IFO_3283_32_uid158375            0
# 20      Acetobacter_pasteurianus_IFO_3283_12_uid158379            0
# 21      Acetobacter_pasteurianus_IFO_3283_12_uid158379            0
# 22                    Acidianus_hospitalis_W1_uid66875            0
# 23                Achromobacter_xylosoxidans_uid205255            0
# 24      Acetobacter_pasteurianus_IFO_3283_03_uid158373            0
# 25      Acetobacter_pasteurianus_IFO_3283_26_uid158531            0
# 26      Acetobacter_pasteurianus_IFO_3283_26_uid158531            0
# 27      Acetobacter_pasteurianus_IFO_3283_26_uid158531            0
# 28     Achromobacter_xylosoxidans_NBRC_15126_uid232243            1
# 29   Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...            0
# ..                                                 ...          ...
# 970               Achromobacter_xylosoxidans_uid205255            0
# 971             Achromobacter_xylosoxidans_A8_uid59899            0
# 972            Acaryochloris_marina_MBIC11017_uid58167            1
# 973     Acetobacter_pasteurianus_IFO_3283_32_uid158375            0
# 974     Acetobacter_pasteurianus_IFO_3283_12_uid158379            0
# 975     Acetobacter_pasteurianus_IFO_3283_32_uid158375            0
# 976               Achromobacter_xylosoxidans_uid205255            0
# 977     Acetobacter_pasteurianus_IFO_3283_22_uid158383            0
# 978     Acetobacter_pasteurianus_IFO_3283_26_uid158531            0
# 979        Acidaminococcus_intestini_RyC_MR95_uid74445            1
# 980            Acaryochloris_marina_MBIC11017_uid58167            1
# 981     Acetobacter_pasteurianus_IFO_3283_12_uid158379            0
# 982            Acaryochloris_marina_MBIC11017_uid58167            1
# 983             Achromobacter_xylosoxidans_A8_uid59899            0
# 984             Achromobacter_xylosoxidans_A8_uid59899            0
# 985             Achromobacter_xylosoxidans_A8_uid59899            0
# 986            Acetobacterium_woodii_DSM_1030_uid88073            1
# 987     Acetobacter_pasteurianus_IFO_3283_26_uid158531            0
# 988     Acetobacter_pasteurianus_IFO_3283_26_uid158531            0
# 989             Achromobacter_xylosoxidans_A8_uid59899            0
# 990     Acetobacter_pasteurianus_IFO_3283_12_uid158379            0
# 991    Achromobacter_xylosoxidans_NBRC_15126_uid232243            1
# 992     Acetobacter_pasteurianus_IFO_3283_22_uid158383            0
# 993     Acetobacter_pasteurianus_IFO_3283_12_uid158379            0
# 994            Acetobacter_pasteurianus_386B_uid214433            0
# 995             Achromobacter_xylosoxidans_A8_uid59899            1
# 996     Acetobacter_pasteurianus_IFO_3283_12_uid158379            0
# 997    Achromobacter_xylosoxidans_NBRC_15126_uid232243            0
# 998     Acetobacter_pasteurianus_IFO_3283_32_uid158375            0
# 999     Acetobacter_pasteurianus_IFO_3283_12_uid158379            0
#
#                                             DTree_pred  NNet_gotit  \
# 0              Acetobacter_pasteurianus_386B_uid214433           0
# 1              Acaryochloris_marina_MBIC11017_uid58167           1
# 2                 Achromobacter_xylosoxidans_uid205255           1
# 3               Achromobacter_xylosoxidans_A8_uid59899           1
# 4              Acetobacter_pasteurianus_386B_uid214433           1
# 5                 Achromobacter_xylosoxidans_uid205255           0
# 6                 Achromobacter_xylosoxidans_uid205255           1
# 7       Acetobacter_pasteurianus_IFO_3283_22_uid158383           0
# 8                 Achromobacter_xylosoxidans_uid205255           0
# 9              Acaryochloris_marina_MBIC11017_uid58167           0
# 10          Acetohalobium_arabaticum_DSM_5501_uid51423           1
# 11               Acholeplasma_laidlawii_PG_8A_uid58901           1
# 12              Achromobacter_xylosoxidans_A8_uid59899           0
# 13                Achromobacter_xylosoxidans_uid205255           0
# 14             Acetobacter_pasteurianus_386B_uid214433           0
# 15   Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...           0
# 16   Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...           1
# 17      Acetobacter_pasteurianus_IFO_3283_12_uid158379           0
# 18                Achromobacter_xylosoxidans_uid205255           1
# 19      Acetobacter_pasteurianus_IFO_3283_12_uid158379           0
# 20      Acetobacter_pasteurianus_IFO_3283_12_uid158379           0
# 21      Acetobacter_pasteurianus_IFO_3283_22_uid158383           0
# 22                    Acidianus_hospitalis_W1_uid66875           0
# 23              Achromobacter_xylosoxidans_A8_uid59899           1
# 24             Acetobacter_pasteurianus_386B_uid214433           0
# 25      Acetobacter_pasteurianus_IFO_3283_22_uid158383           1
# 26      Acetobacter_pasteurianus_IFO_3283_03_uid158373           0
# 27      Acetobacter_pasteurianus_IFO_3283_26_uid158531           0
# 28              Achromobacter_xylosoxidans_A8_uid59899           1
# 29      Acetobacter_pasteurianus_IFO_3283_03_uid158373           0
# ..                                                 ...         ...
# 970               Achromobacter_xylosoxidans_uid205255           1
# 971     Acetobacter_pasteurianus_IFO_3283_07_uid158381           1
# 972            Acaryochloris_marina_MBIC11017_uid58167           1
# 973            Acetobacter_pasteurianus_386B_uid214433           0
# 974  Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...           0
# 975     Acetobacter_pasteurianus_IFO_3283_22_uid158383           0
# 976    Achromobacter_xylosoxidans_NBRC_15126_uid232243           0
# 977     Acetobacter_pasteurianus_IFO_3283_22_uid158383           0
# 978     Acetobacter_pasteurianus_IFO_3283_26_uid158531           0
# 979        Acidaminococcus_intestini_RyC_MR95_uid74445           1
# 980            Acaryochloris_marina_MBIC11017_uid58167           1
# 981     Acetobacter_pasteurianus_IFO_3283_07_uid158381           0
# 982            Acaryochloris_marina_MBIC11017_uid58167           1
# 983     Acetobacter_pasteurianus_IFO_3283_26_uid158531           1
# 984             Achromobacter_xylosoxidans_A8_uid59899           1
# 985               Achromobacter_xylosoxidans_uid205255           1
# 986            Acetobacterium_woodii_DSM_1030_uid88073           1
# 987     Acetobacter_pasteurianus_IFO_3283_07_uid158381           0
# 988            Acetobacter_pasteurianus_386B_uid214433           0
# 989               Achromobacter_xylosoxidans_uid205255           1
# 990     Acetobacter_pasteurianus_IFO_3283_22_uid158383           0
# 991               Achromobacter_xylosoxidans_uid205255           1
# 992            Acetobacter_pasteurianus_386B_uid214433           0
# 993  Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...           0
# 994     Acetobacter_pasteurianus_IFO_3283_26_uid158531           0
# 995             Achromobacter_xylosoxidans_A8_uid59899           1
# 996            Acetobacter_pasteurianus_386B_uid214433           0
# 997               Achromobacter_xylosoxidans_uid205255           0
# 998     Acetobacter_pasteurianus_IFO_3283_32_uid158375           0
# 999            Acetobacter_pasteurianus_386B_uid214433           0
#
#                                            NNet_pred  AdaBoost_gotit  \
# 0     Acetobacter_pasteurianus_IFO_3283_12_uid158379               0
# 1            Acaryochloris_marina_MBIC11017_uid58167               1
# 2               Achromobacter_xylosoxidans_uid205255               0
# 3             Achromobacter_xylosoxidans_A8_uid59899               1
# 4            Acaryochloris_marina_MBIC11017_uid58167               0
# 5             Achromobacter_xylosoxidans_A8_uid59899               0
# 6    Achromobacter_xylosoxidans_NBRC_15126_uid232243               0
# 7     Acetobacter_pasteurianus_IFO_3283_32_uid158375               0
# 8             Achromobacter_xylosoxidans_A8_uid59899               0
# 9            Acaryochloris_marina_MBIC11017_uid58167               0
# 10        Acetohalobium_arabaticum_DSM_5501_uid51423               0
# 11             Acholeplasma_laidlawii_PG_8A_uid58901               0
# 12            Achromobacter_xylosoxidans_A8_uid59899               0
# 13              Achromobacter_xylosoxidans_uid205255               0
# 1      Acaryochloris_marina_MBIC11017_uid58167                  1
# 2       Achromobacter_xylosoxidans_A8_uid59899                  1
# 3       Achromobacter_xylosoxidans_A8_uid59899                  1
# 4    Acidilobus_saccharovorans_345_15_uid51395                  1
# 5       Achromobacter_xylosoxidans_A8_uid59899                  0
# 6       Achromobacter_xylosoxidans_A8_uid59899                  1
# 7      Acaryochloris_marina_MBIC11017_uid58167                  0
# 8       Achromobacter_xylosoxidans_A8_uid59899                  0
# 9      Acaryochloris_marina_MBIC11017_uid58167                  0
# 10   Acidilobus_saccharovorans_345_15_uid51395                  1
# 11     Acetobacterium_woodii_DSM_1030_uid88073                  1
# 12      Achromobacter_xylosoxidans_A8_uid59899                  0
# 13      Achromobacter_xylosoxidans_A8_uid59899                  1
# 14     Acaryochloris_marina_MBIC11017_uid58167                  0
# 15     Acaryochloris_marina_MBIC11017_uid58167                  0
# 16     Acetobacterium_woodii_DSM_1030_uid88073                  1
# 17     Acaryochloris_marina_MBIC11017_uid58167                  0
# 18      Achromobacter_xylosoxidans_A8_uid59899                  1
# 19     Acaryochloris_marina_MBIC11017_uid58167                  0
# 20     Acaryochloris_marina_MBIC11017_uid58167                  0
# 21     Acaryochloris_marina_MBIC11017_uid58167                  0
# 22            Acidianus_hospitalis_W1_uid66875                  0
# 23      Achromobacter_xylosoxidans_A8_uid59899                  1
# 24     Acaryochloris_marina_MBIC11017_uid58167                  1
# 25     Acaryochloris_marina_MBIC11017_uid58167                  1
# 26     Acaryochloris_marina_MBIC11017_uid58167                  0
# 27     Acaryochloris_marina_MBIC11017_uid58167                  0
# 28      Achromobacter_xylosoxidans_A8_uid59899                  1
# 29     Acaryochloris_marina_MBIC11017_uid58167                  0
# ..                                         ...                ...
# 970     Achromobacter_xylosoxidans_A8_uid59899                  1
# 971    Acaryochloris_marina_MBIC11017_uid58167                  1
# 972    Acaryochloris_marina_MBIC11017_uid58167                  1
# 973    Acaryochloris_marina_MBIC11017_uid58167                  0
# 974    Acaryochloris_marina_MBIC11017_uid58167                  1
# 975    Acaryochloris_marina_MBIC11017_uid58167                  0
# 976     Achromobacter_xylosoxidans_A8_uid59899                  0
# 977    Acaryochloris_marina_MBIC11017_uid58167                  0
# 978    Acaryochloris_marina_MBIC11017_uid58167                  0
# 979    Acaryochloris_marina_MBIC11017_uid58167                  1
# 980    Acaryochloris_marina_MBIC11017_uid58167                  1
# 981    Acaryochloris_marina_MBIC11017_uid58167                  0
# 982    Acaryochloris_marina_MBIC11017_uid58167                  1
# 983     Achromobacter_xylosoxidans_A8_uid59899                  1
# 984     Achromobacter_xylosoxidans_A8_uid59899                  1
# 985     Achromobacter_xylosoxidans_A8_uid59899                  1
# 986    Acetobacterium_woodii_DSM_1030_uid88073                  1
# 987    Acaryochloris_marina_MBIC11017_uid58167                  0
# 988    Acaryochloris_marina_MBIC11017_uid58167                  0
# 989     Achromobacter_xylosoxidans_A8_uid59899                  1
# 990    Acaryochloris_marina_MBIC11017_uid58167                  0
# 991     Achromobacter_xylosoxidans_A8_uid59899                  0
# 992    Acaryochloris_marina_MBIC11017_uid58167                  0
# 993    Acaryochloris_marina_MBIC11017_uid58167                  0
# 994    Acaryochloris_marina_MBIC11017_uid58167                  0
# 995     Achromobacter_xylosoxidans_A8_uid59899                  1
# 996    Acaryochloris_marina_MBIC11017_uid58167                  0
# 997     Achromobacter_xylosoxidans_A8_uid59899                  0
# 998    Acaryochloris_marina_MBIC11017_uid58167                  0
# 999    Acaryochloris_marina_MBIC11017_uid58167                  0
#
#                                     Naive_Bayes_pred  QDA_gotit  \
# 0            Acetobacter_pasteurianus_386B_uid214433          0
# 1            Acaryochloris_marina_MBIC11017_uid58167          1
# 2               Achromobacter_xylosoxidans_uid205255          1
# 3             Achromobacter_xylosoxidans_A8_uid59899          1
# 4            Acaryochloris_marina_MBIC11017_uid58167          1
# 5             Achromobacter_xylosoxidans_A8_uid59899          0
# 6    Achromobacter_xylosoxidans_NBRC_15126_uid232243          1
# 7      Acetobacter_pasteurianus_IFO_3283_01_uid59279          0
# 8             Achromobacter_xylosoxidans_A8_uid59899          0
# 9            Acaryochloris_marina_MBIC11017_uid58167          0
# 10        Acetohalobium_arabaticum_DSM_5501_uid51423          1
# 11             Acholeplasma_laidlawii_PG_8A_uid58901          1
# 12            Achromobacter_xylosoxidans_A8_uid59899          0
# 13   Achromobacter_xylosoxidans_NBRC_15126_uid232243          0
# 14    Acetobacter_pasteurianus_IFO_3283_03_uid158373          0
# 15    Acetobacter_pasteurianus_IFO_3283_12_uid158379          0
# 16           Acetobacterium_woodii_DSM_1030_uid88073          1
# 17    Acetobacter_pasteurianus_IFO_3283_12_uid158379          0
# 18            Achromobacter_xylosoxidans_A8_uid59899          1
# 19    Acetobacter_pasteurianus_IFO_3283_12_uid158379          1
# 20    Acetobacter_pasteurianus_IFO_3283_12_uid158379          0
# 21           Acetobacter_pasteurianus_386B_uid214433          0
# 22        Acetohalobium_arabaticum_DSM_5501_uid51423          0
# 23              Achromobacter_xylosoxidans_uid205255          0
# 24    Acetobacter_pasteurianus_IFO_3283_26_uid158531          1
# 25    Acetobacter_pasteurianus_IFO_3283_32_uid158375          0
# 26       Acidaminococcus_intestini_RyC_MR95_uid74445          0
# 27    Acetobacter_pasteurianus_IFO_3283_12_uid158379          0
# 28            Achromobacter_xylosoxidans_A8_uid59899          1
# 29           Acaryochloris_marina_MBIC11017_uid58167          0
# ..                                               ...        ...
# 970  Achromobacter_xylosoxidans_NBRC_15126_uid232243          1
# 971           Achromobacter_xylosoxidans_A8_uid59899          0
# 972          Acaryochloris_marina_MBIC11017_uid58167          1
# 973   Acetobacter_pasteurianus_IFO_3283_32_uid158375          0
# 974   Acetobacter_pasteurianus_IFO_3283_32_uid158375          0
# 975    Acetobacter_pasteurianus_IFO_3283_01_uid59279          0
# 976           Achromobacter_xylosoxidans_A8_uid59899          1
# 977    Acetobacter_pasteurianus_IFO_3283_01_uid59279          0
# 978   Acetobacter_pasteurianus_IFO_3283_12_uid158379          0
# 979      Acidaminococcus_intestini_RyC_MR95_uid74445          1
# 980          Acaryochloris_marina_MBIC11017_uid58167          1
# 981          Acetobacter_pasteurianus_386B_uid214433          0
# 982          Acaryochloris_marina_MBIC11017_uid58167          1
# 983           Achromobacter_xylosoxidans_A8_uid59899          1
# 984  Achromobacter_xylosoxidans_NBRC_15126_uid232243          0
# 985           Achromobacter_xylosoxidans_A8_uid59899          1
# 986          Acetobacterium_woodii_DSM_1030_uid88073          1
# 987   Acetobacter_pasteurianus_IFO_3283_26_uid158531          0
# 988   Acetobacter_pasteurianus_IFO_3283_32_uid158375          0
# 989           Achromobacter_xylosoxidans_A8_uid59899          1
# 990   Acetobacter_pasteurianus_IFO_3283_12_uid158379          0
# 991  Achromobacter_xylosoxidans_NBRC_15126_uid232243          1
# 992    Acetobacter_pasteurianus_IFO_3283_01_uid59279          0
# 993   Acetobacter_pasteurianus_IFO_3283_12_uid158379          0
# 994   Acetobacter_pasteurianus_IFO_3283_26_uid158531          0
# 995           Achromobacter_xylosoxidans_A8_uid59899          1
# 996   Acetobacter_pasteurianus_IFO_3283_12_uid158379          0
# 997  Achromobacter_xylosoxidans_NBRC_15126_uid232243          0
# 998   Acetobacter_pasteurianus_IFO_3283_12_uid158379          0
# 999   Acetobacter_pasteurianus_IFO_3283_12_uid158379          0
#
#                                               QDA_pred
# 0        Acetobacter_pasteurianus_IFO_3283_01_uid59279
# 1              Acaryochloris_marina_MBIC11017_uid58167
# 2                 Achromobacter_xylosoxidans_uid205255
# 3               Achromobacter_xylosoxidans_A8_uid59899
# 4              Acaryochloris_marina_MBIC11017_uid58167
# 5               Achromobacter_xylosoxidans_A8_uid59899
# 6      Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 7        Acetobacter_pasteurianus_IFO_3283_01_uid59279
# 8               Achromobacter_xylosoxidans_A8_uid59899
# 9              Acaryochloris_marina_MBIC11017_uid58167
# 10          Acetohalobium_arabaticum_DSM_5501_uid51423
# 11               Acholeplasma_laidlawii_PG_8A_uid58901
# 12              Achromobacter_xylosoxidans_A8_uid59899
# 13                Achromobacter_xylosoxidans_uid205255
# 14      Acetobacter_pasteurianus_IFO_3283_07_uid158381
# 15      Acetobacter_pasteurianus_IFO_3283_26_uid158531
# 16             Acetobacterium_woodii_DSM_1030_uid88073
# 17      Acetobacter_pasteurianus_IFO_3283_12_uid158379
# 18              Achromobacter_xylosoxidans_A8_uid59899
# 19       Acetobacter_pasteurianus_IFO_3283_01_uid59279
# 20             Acetobacter_pasteurianus_386B_uid214433
# 21      Acetobacter_pasteurianus_IFO_3283_32_uid158375
# 22          Acetohalobium_arabaticum_DSM_5501_uid51423
# 23     Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 24      Acetobacter_pasteurianus_IFO_3283_26_uid158531
# 25      Acetobacter_pasteurianus_IFO_3283_26_uid158531
# 26      Acetobacter_pasteurianus_IFO_3283_26_uid158531
# 27      Acetobacter_pasteurianus_IFO_3283_26_uid158531
# 28              Achromobacter_xylosoxidans_A8_uid59899
# 29   Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...
# ..                                                 ...
# 970    Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 971  Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...
# 972            Acaryochloris_marina_MBIC11017_uid58167
# 973     Acetobacter_pasteurianus_IFO_3283_32_uid158375
# 974     Acetobacter_pasteurianus_IFO_3283_12_uid158379
# 975      Acetobacter_pasteurianus_IFO_3283_01_uid59279
# 976               Achromobacter_xylosoxidans_uid205255
# 977     Acetobacter_pasteurianus_IFO_3283_26_uid158531
# 978            Acetobacter_pasteurianus_386B_uid214433
# 979        Acidaminococcus_intestini_RyC_MR95_uid74445
# 980            Acaryochloris_marina_MBIC11017_uid58167
# 981     Acetobacter_pasteurianus_IFO_3283_12_uid158379
# 982            Acaryochloris_marina_MBIC11017_uid58167
# 983             Achromobacter_xylosoxidans_A8_uid59899
# 984               Achromobacter_xylosoxidans_uid205255
# 985             Achromobacter_xylosoxidans_A8_uid59899
# 986            Acetobacterium_woodii_DSM_1030_uid88073
# 987     Acetobacter_pasteurianus_IFO_3283_07_uid158381
# 988     Acetobacter_pasteurianus_IFO_3283_22_uid158383
# 989             Achromobacter_xylosoxidans_A8_uid59899
# 990     Acetobacter_pasteurianus_IFO_3283_12_uid158379
# 991               Achromobacter_xylosoxidans_uid205255
# 992      Acetobacter_pasteurianus_IFO_3283_01_uid59279
# 993  Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...
# 994      Acetobacter_pasteurianus_IFO_3283_01_uid59279
# 995             Achromobacter_xylosoxidans_A8_uid59899
# 996  Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...
# 997    Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 998      Acetobacter_pasteurianus_IFO_3283_01_uid59279
# 999     Acetobacter_pasteurianus_IFO_3283_12_uid158379
#
# [1000 rows x 17 columns]

# %%
def randForest():
    if verbose:  print("Random Forest Classification")
    rf_regr = RandomForestClassifier(max_depth=20, random_state=0, n_estimators=100, n_jobs=6)
    rf_regr.fit(X_train, y_train)
    return rf_regr

# %%
rf_cl = randForest()
score = rf_cl.score(X_test, y_test)
score
# Out:
# Random Forest Classification
# 0.48999999999999999

# %%
predicted = rf_cl.predict(X_test)

# %%
pd_res = pd.DataFrame({"Ground_Truth": y_test, "Got_it": y_test==predicted, "Predicted": predicted})
pd_res
# Out:
#                                           Ground_Truth  Got_it  \
# 0       Acetobacter_pasteurianus_IFO_3283_07_uid158381   False
# 1           Acetohalobium_arabaticum_DSM_5501_uid51423    True
# 2                 Achromobacter_xylosoxidans_uid205255   False
# 3      Achromobacter_xylosoxidans_NBRC_15126_uid232243    True
# 4      Achromobacter_xylosoxidans_NBRC_15126_uid232243    True
# 5                     Acidianus_hospitalis_W1_uid66875    True
# 6        Acetobacter_pasteurianus_IFO_3283_01_uid59279   False
# 7                Acholeplasma_laidlawii_PG_8A_uid58901    True
# 8                 Achromobacter_xylosoxidans_uid205255    True
# 9           Acetohalobium_arabaticum_DSM_5501_uid51423    True
# 10      Acetobacter_pasteurianus_IFO_3283_03_uid158373   False
# 11   Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...   False
# 12     Achromobacter_xylosoxidans_NBRC_15126_uid232243    True
# 13     Achromobacter_xylosoxidans_NBRC_15126_uid232243   False
# 14               Acholeplasma_laidlawii_PG_8A_uid58901   False
# 15      Acetobacter_pasteurianus_IFO_3283_12_uid158379   False
# 16      Acetobacter_pasteurianus_IFO_3283_07_uid158381   False
# 17       Acetobacter_pasteurianus_IFO_3283_01_uid59279   False
# 18              Achromobacter_xylosoxidans_A8_uid59899   False
# 19              Achromobacter_xylosoxidans_A8_uid59899    True
# 20      Acetobacter_pasteurianus_IFO_3283_07_uid158381   False
# 21             Acetobacter_pasteurianus_386B_uid214433   False
# 22             Acaryochloris_marina_MBIC11017_uid58167    True
# 23                Achromobacter_xylosoxidans_uid205255    True
# 24      Acetobacter_pasteurianus_IFO_3283_22_uid158383   False
# 25     Achromobacter_xylosoxidans_NBRC_15126_uid232243    True
# 26      Acetobacter_pasteurianus_IFO_3283_12_uid158379   False
# 27         Acidaminococcus_intestini_RyC_MR95_uid74445    True
# 28     Achromobacter_xylosoxidans_NBRC_15126_uid232243   False
# 29             Acaryochloris_marina_MBIC11017_uid58167    True
# ..                                                 ...     ...
# 170             Achromobacter_xylosoxidans_A8_uid59899    True
# 171     Acetobacter_pasteurianus_IFO_3283_22_uid158383   False
# 172    Achromobacter_xylosoxidans_NBRC_15126_uid232243   False
# 173         Acetohalobium_arabaticum_DSM_5501_uid51423    True
# 174            Acaryochloris_marina_MBIC11017_uid58167    True
# 175             Achromobacter_xylosoxidans_A8_uid59899   False
# 176        Acidaminococcus_intestini_RyC_MR95_uid74445   False
# 177            Acetobacter_pasteurianus_386B_uid214433   False
# 178          Acidilobus_saccharovorans_345_15_uid51395    True
# 179            Acetobacterium_woodii_DSM_1030_uid88073    True
# 180    Achromobacter_xylosoxidans_NBRC_15126_uid232243   False
# 181            Acetobacterium_woodii_DSM_1030_uid88073    True
# 182          Acidilobus_saccharovorans_345_15_uid51395    True
# 183            Acetobacterium_woodii_DSM_1030_uid88073    True
# 184     Acetobacter_pasteurianus_IFO_3283_26_uid158531    True
# 185     Acetobacter_pasteurianus_IFO_3283_03_uid158373   False
# 186     Acetobacter_pasteurianus_IFO_3283_22_uid158383   False
# 187            Acaryochloris_marina_MBIC11017_uid58167    True
# 188             Achromobacter_xylosoxidans_A8_uid59899   False
# 189    Achromobacter_xylosoxidans_NBRC_15126_uid232243   False
# 190             Achromobacter_xylosoxidans_A8_uid59899    True
# 191               Achromobacter_xylosoxidans_uid205255   False
# 192            Acaryochloris_marina_MBIC11017_uid58167    True
# 193             Achromobacter_xylosoxidans_A8_uid59899    True
# 194        Acidaminococcus_intestini_RyC_MR95_uid74445    True
# 195               Achromobacter_xylosoxidans_uid205255   False
# 196     Acetobacter_pasteurianus_IFO_3283_12_uid158379   False
# 197               Achromobacter_xylosoxidans_uid205255   False
# 198                   Acidianus_hospitalis_W1_uid66875    True
# 199      Acetobacter_pasteurianus_IFO_3283_01_uid59279   False
#
#                                              Predicted
# 0               Achromobacter_xylosoxidans_A8_uid59899
# 1           Acetohalobium_arabaticum_DSM_5501_uid51423
# 2      Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 3      Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 4      Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 5                     Acidianus_hospitalis_W1_uid66875
# 6       Acetobacter_pasteurianus_IFO_3283_32_uid158375
# 7                Acholeplasma_laidlawii_PG_8A_uid58901
# 8                 Achromobacter_xylosoxidans_uid205255
# 9           Acetohalobium_arabaticum_DSM_5501_uid51423
# 10              Achromobacter_xylosoxidans_A8_uid59899
# 11             Acaryochloris_marina_MBIC11017_uid58167
# 12     Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 13              Achromobacter_xylosoxidans_A8_uid59899
# 14          Acetohalobium_arabaticum_DSM_5501_uid51423
# 15      Acetobacter_pasteurianus_IFO_3283_07_uid158381
# 16      Acetobacter_pasteurianus_IFO_3283_03_uid158373
# 17             Acetobacter_pasteurianus_386B_uid214433
# 18             Acaryochloris_marina_MBIC11017_uid58167
# 19              Achromobacter_xylosoxidans_A8_uid59899
# 20         Acidaminococcus_intestini_RyC_MR95_uid74445
# 21   Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...
# 22             Acaryochloris_marina_MBIC11017_uid58167
# 23                Achromobacter_xylosoxidans_uid205255
# 24             Acetobacter_pasteurianus_386B_uid214433
# 25     Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 26               Acholeplasma_laidlawii_PG_8A_uid58901
# 27         Acidaminococcus_intestini_RyC_MR95_uid74445
# 28              Achromobacter_xylosoxidans_A8_uid59899
# 29             Acaryochloris_marina_MBIC11017_uid58167
# ..                                                 ...
# 170             Achromobacter_xylosoxidans_A8_uid59899
# 171      Acetobacter_pasteurianus_IFO_3283_01_uid59279
# 172             Achromobacter_xylosoxidans_A8_uid59899
# 173         Acetohalobium_arabaticum_DSM_5501_uid51423
# 174            Acaryochloris_marina_MBIC11017_uid58167
# 175    Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 176     Acetobacter_pasteurianus_IFO_3283_07_uid158381
# 177  Acetobacter_pasteurianus_IFO_3283_01_42C_uid15...
# 178          Acidilobus_saccharovorans_345_15_uid51395
# 179            Acetobacterium_woodii_DSM_1030_uid88073
# 180               Achromobacter_xylosoxidans_uid205255
# 181            Acetobacterium_woodii_DSM_1030_uid88073
# 182          Acidilobus_saccharovorans_345_15_uid51395
# 183            Acetobacterium_woodii_DSM_1030_uid88073
# 184     Acetobacter_pasteurianus_IFO_3283_26_uid158531
# 185     Acetobacter_pasteurianus_IFO_3283_12_uid158379
# 186            Acetobacter_pasteurianus_386B_uid214433
# 187            Acaryochloris_marina_MBIC11017_uid58167
# 188               Achromobacter_xylosoxidans_uid205255
# 189             Achromobacter_xylosoxidans_A8_uid59899
# 190             Achromobacter_xylosoxidans_A8_uid59899
# 191             Achromobacter_xylosoxidans_A8_uid59899
# 192            Acaryochloris_marina_MBIC11017_uid58167
# 193             Achromobacter_xylosoxidans_A8_uid59899
# 194        Acidaminococcus_intestini_RyC_MR95_uid74445
# 195    Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 196     Acetobacter_pasteurianus_IFO_3283_03_uid158373
# 197    Achromobacter_xylosoxidans_NBRC_15126_uid232243
# 198                   Acidianus_hospitalis_W1_uid66875
# 199            Acetobacter_pasteurianus_386B_uid214433
#
# [200 rows x 3 columns]

# %%
def svr():
    if verbose:  print("Support Vector Machine regression")
    svr_rbf = SVC(kernel='rbf', gamma='auto', cache_size=1000)
    svr_rbf.fit(X_train, y_train)
    return svr_rbf

# %%
svr_rbf = svr()
svr_pred = error_and_corr(svr_rbf)
some_predictions(svr_pred)
# Out:
# Support Vector Machine regression
# Pearson correlation	: *0.396*
# Mean squared error	: 450474419.036
# Expected values 	: 20750.00	60975.00	6943.00	43743.00	37827.00	35247.00	14456.00	20457.00	63387.00	64819.00
# Predicted values 	: 36217.67	41153.16	37715.84	40516.99	37342.60	37451.71	40153.87	36616.17	39658.96	39800.07

# %%
def k_neigh():
    if verbose:  print("K neighbours")
    neigh = KNeighborsRegressor(n_neighbors=20, n_jobs=6)
    neigh.fit(X_train, y_train)
    return neigh

# %%
neigh = k_neigh()
n_pred = error_and_corr(neigh)
some_predictions(n_pred)
# Out:
# K neighbours
# Pearson correlation	: *0.671*
# Mean squared error	: 260134584.829
# Expected values 	: 20750.00	60975.00	6943.00	43743.00	37827.00	35247.00	14456.00	20457.00	63387.00	64819.00
# Predicted values 	: 26281.15	56710.45	5391.20	32758.30	32224.10	27731.05	38815.25	26915.65	37706.80	40203.70

# %%
def elas_net():
    if verbose:  print("Elastic Net")
    elastic_net = ElasticNet(l1_ratio=0.5, random_state=0)
    elastic_net.fit(X_train, y_train)
    return elastic_net

# %%
e_net = elas_net()
e_pred = error_and_corr(e_net)
some_predictions(e_pred)

# %%
def nn():
    if verbose:  print("Neural Network")
    nnm = MLPRegressor(hidden_layer_sizes=(100,100,), verbose=False, tol=0.000100)
    nnm.fit(X_train, y_train)
    return nnm

# %%
nn_m = nn()
nn_pred = error_and_corr(nn_m)
some_predictions(nn_pred)

# %%
models = [linReg, randForest, svr, k_neigh, elas_net, nn]

# %%
results = {}
for model in tqdm(models):
    print("******************************************")
    m = model()
    pred = error_and_corr(m)
    # some_predictions(pred)
    pearson, err = error_and_corr(m, re_val=True)
    results[model.__name__] = {"pearson": pearson, "err": err}

# %%
pred = error_and_corr(models[1](), display=False)

# %%
pd.DataFrame([pred, y_test.values])

# %%
from datetime import datetime
file_results = "results.csv"
file_results = osp.join(folder, file_results)

# %%
with open(file_results, "a") as f:
    f.write(str(datetime.now())[:16] + "," + str(param) + "," + "\n")
    f.write(",".join(results.keys()) + "\n")
    f.write(",".join([f"{v['pearson']:.3f}" for v in results.values()]) + "\n")
    f.write(",".join([f"{v['err']:.3f}" for v in results.values()]) + "\n")
    print(f"Results written in {file_results}")

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html

# %%
names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()]

# %%
results = {}
for name, clf in tqdm(zip(names, classifiers), total=len(names), desc="Classifiers"):
    clf.fit(X_train, y_train)
    score = clf.score(X_test, y_test)
    results[name] = score
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-206-379432ea3558> in <module>()
#       1 results = {}
#       2 for name, clf in tqdm(zip(names, classifiers), total=len(names)):
# ----> 3     clf.fit(X_train, y_train)
#       4     score = clf.score(X_test, y_test)
#       5     results[name] = score
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpc.py in fit(self, X, y)
#     632                                  % self.multi_class)
#     633
# --> 634         self.base_estimator_.fit(X, y)
#     635
#     636         if self.n_classes_ > 2:
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/multiclass.py in fit(self, X, y)
#     213                 "not %s" % self.label_binarizer_.classes_[i],
#     214                 self.label_binarizer_.classes_[i]])
# --> 215             for i, column in enumerate(columns))
#     216
#     217         return self
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/multiclass.py in _fit_binary(estimator, X, y, classes)
#      78     else:
#      79         estimator = clone(estimator)
# ---> 80         estimator.fit(X, y)
#      81     return estimator
#      82
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpc.py in fit(self, X, y)
#     210             optima = [self._constrained_optimization(obj_func,
#     211                                                      self.kernel_.theta,
# --> 212                                                      self.kernel_.bounds)]
#     213
#     214             # Additional runs are performed from log-uniform chosen initial
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpc.py in _constrained_optimization(self, obj_func, initial_theta, bounds)
#     428         if self.optimizer == "fmin_l_bfgs_b":
#     429             theta_opt, func_min, convergence_dict = \
# --> 430                 fmin_l_bfgs_b(obj_func, initial_theta, bounds=bounds)
#     431             if convergence_dict["warnflag"] != 0:
#     432                 warnings.warn("fmin_l_bfgs_b terminated abnormally with the "
#
# /opt/anaconda3/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# /opt/anaconda3/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# /opt/anaconda3/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     283     else:
#     284         def func_and_grad(x):
# --> 285             f = fun(x, *args)
#     286             g = jac(x, *args)
#     287             return f, g
#
# /opt/anaconda3/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     298     def function_wrapper(*wrapper_args):
#     299         ncalls[0] += 1
# --> 300         return function(*(wrapper_args + args))
#     301
#     302     return ncalls, function_wrapper
#
# /opt/anaconda3/lib/python3.6/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      61     def __call__(self, x, *args):
#      62         self.x = numpy.asarray(x).copy()
# ---> 63         fg = self.fun(x, *args)
#      64         self.jac = fg[1]
#      65         return fg[0]
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpc.py in obj_func(theta, eval_gradient)
#     202                 if eval_gradient:
#     203                     lml, grad = self.log_marginal_likelihood(
# --> 204                         theta, eval_gradient=True)
#     205                     return -lml, -grad
#     206                 else:
#
# /opt/anaconda3/lib/python3.6/site-packages/sklearn/gaussian_process/gpc.py in log_marginal_likelihood(self, theta, eval_gradient)
#     355         # XXX: Get rid of the np.diag() in the next line
#     356         R = W_sr[:, np.newaxis] * cho_solve((L, True), np.diag(W_sr))  # Line 7
# --> 357         C = solve(L, W_sr[:, np.newaxis] * K)  # Line 8
#     358         # Line 9: (use einsum to compute np.diag(C.T.dot(C))))
#     359         s_2 = -0.5 * (np.diag(K) - np.einsum('ij, ij -> j', C, C)) \
#
# /opt/anaconda3/lib/python3.6/site-packages/scipy/linalg/basic.py in solve(a, b, sym_pos, lower, overwrite_a, overwrite_b, debug, check_finite, assume_a, transposed)
#     213         gecon, getrf, getrs = get_lapack_funcs(('gecon', 'getrf', 'getrs'),
#     214                                                (a1, b1))
# --> 215         lu, ipvt, info = getrf(a1, overwrite_a=overwrite_a)
#     216         _solve_check(n, info)
#     217         x, info = getrs(lu, ipvt, b1,
#
# KeyboardInterrupt:

# %% [markdown]
# ### End of the script.
# Sylvain @GIS

# %% [markdown]
# ## Keep other methods

# %% [markdown]
# ML stuff

# %%
def scale_minmax(df, single_col=False):
    df = df + 1
    df = df.apply(np.log2)
    if single_col:
        return MinMaxScaler().fit_transform(df.values.reshape(-1, 1))
    else:
        return MinMaxScaler().fit_transform(df)

# %%
def error_and_corr(model, display=True, re_val=False):
    prediction = model.predict(X_test)
    pearson = np.corrcoef(prediction, y_test)[0, 1]
    mean_square_err = mean_squared_error(y_test, prediction)
    if re_val:
        return pearson, mean_square_err
    if display:
        print(f"Pearson correlation\t: *{pearson:.3f}*")
        print(f"Mean squared error\t: {mean_square_err:.3f}")
    return prediction

# %%
def some_predictions(pred):
    print("Expected values \t: " + "\t".join([f"{n:.2f}" for n in y_test[:10]]))
    print("Predicted values \t: " + "\t".join([f"{n:.2f}" for n in pred[:10]]))

# %% [markdown]
# kmers stuff

# %%
def window(fseq, window_size=53):
    for i in range(len(fseq) - window_size + 1):
        yield fseq[i:i+window_size]

# %%
def kmer_pkl_path(k, fna_path):
    path_gbk = fna_path.replace(".fna", ".gbk")
    assert os.path.isfile(path_gbk), f"{fna_path} DOESN'T have a .gbk file ??"
    
    with open(path_gbk) as gbk:
        description=gbk.read()  #.replace('\n', '')
        
    identificator = 'db_xref="taxon:'
    taxo_start = description.find(identificator)
    taxo = description[taxo_start+len(identificator):
                       taxo_start+description[taxo_start:].find('"\n')]
    assert len(taxo) < 10, f"The taxo id search failed, found an id of length {len(taxo)}..."
    
    # TODO: ADD full path of the original file in the file name, or maybe in the .pkl
    
    return os.path.join(path_kmer_freq, str(k), taxo + ".pkl")

# %%
def kmer_freq_to_file(kmer_dic, freq_path):
    with open(freq_path, 'wb') as f_out:
        pickle.dump(kmer_dic, f_out)
