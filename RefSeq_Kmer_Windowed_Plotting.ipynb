# %% [markdown]
# # Exploring the reference database
# Let's see what properties we can find :)

# %% [markdown]
# ## Structure
# In `genome/`, there's multiple sub-folder, we will start with `Bacteria`
# It then contains all recorded species/strands in individual folders

# %% [markdown]
# ## Content of each species/strand folder
# In each folder there's:
# - .ASN with
#  - `taxname "Acetobacter pasteurianus IFO 3283-32"`
#  - `db "taxon", tag id 634457`
#  - `genus "Acetobacter", species "pasteurianus"`
#  - `mod { {subtype strain, subname "IFO 3283" }, { subtype substrain, subname "IFO 3283-32" } },`
#  - `lineage "Bacteria; Proteobacteria; Alphaproteobacteria; Rhodospirillales; Acetobacteraceae; Acetobacter",`
# - .FAA
#  - with multiple ">gi|384064451|ref|YP_005479409.1| hypothetical protein APA32_44160 [Acetobacter pasteurianus IFO 3283-32]"
#  - and probably the amino-acid sequence for each of these proteins
# - .FFN
#  - multiple ">gi|384064450|ref|NC_017102.1|:c562-116 Acetobacter pasteurianus IFO 3283-32 plasmid pAPA32-040, complete sequence"
#  - probably DNA sequence
# - .FNA
#  - Also DNA
# - .GBK : Human readable format with most info !
#  - have an identifier `/db_xref="taxon:634457"`
# - .GFF with `##species http://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=634457`
# - .RPT
#  - seem good with simple Python INI config file format:
#    - `DNA  length = 3035`
#    - `Taxname: Acetobacter pasteurianus IFO 3283-32`
#    - `Taxid: 634457`

# %% [markdown]
# http://defindit.com/readme_files/ncbi_file_extension_format.html

# %% [raw]
# .asn	genome record in asn.1 format
# .faa	protein sequences in fasta format, text file
# .ffn	protein coding portions of the genome segments
# .fna	genome fasta sequence
# .frn	rna coding portions of the genome segments
# .gbk	genome in genbank file format
# .gff	genome features
# .ptt	protein table
# .rnt	rna table
# .rpt	summary report
# .val	binary file (genome project?)

# %% [markdown]
# What we need is the taxo id, name, and the DNA, which can be found in:
#  - .gbk for the taxo and name
#  - .fna for the sequence

# %% [markdown]
# #### File marker
# https://www.ncbi.nlm.nih.gov/books/NBK21091/table/ch18.T.refseq_accession_numbers_and_mole/?report=objectonly <br>
# `NC_	Genomic	Complete genomic molecule, usually reference assembly`
#
# #### Status
# https://www.ncbi.nlm.nih.gov/books/NBK21091/table/ch18.T.refseq_status_codes/?report=objectonly <br>
# in `COMMENT` : VALIDATED > REVIEWED > PROVISIONAL > ...

# %% [markdown]
# ## Coding
# ### Import and Paths

# %%
import os
import pandas as pd
import numpy as np
import configparser
import pickle
from Bio import SeqIO
from time import time
from tqdm import tqdm_notebook as tqdm

# %%
path_ref_db = "/mnt/genomeDB/ncbi/genomes/Bacteria/"
path_kmer_freq = "/home/sjriondet/Data/Kmer_frequencies/"

# %%
os.chdir(path_ref_db)

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Tests

# %%
path_4mer = "4_V2/"
path_4mer = os.path.join(path_kmer_freq, path_4mer)

# %%
names = []
counts = []
for f in os.scandir(path_4mer):
    if f.name.endswith(".pd"):
        with open(f, 'rb') as file:
            names.append(os.path.splitext(f.name)[0])
#             counts.append(pickle.load(file))099

# %%
len(names)
# Out:
# 18

# %%
names
# Out:
# ['634457__Acetobacter_pasteurianus_IFO_3283_32_uid158375',
#  '591001__Acidaminococcus_fermentans_DSM_20731_uid43471',
#  '931626__Acetobacterium_woodii_DSM_1030_uid88073',
#  '634455__Acetobacter_pasteurianus_IFO_3283_22_uid158383',
#  '1266844__Acetobacter_pasteurianus_386B_uid214433',
#  '1216976__Achromobacter_xylosoxidans_NBRC_15126_uid232243',
#  '1167634__Achromobacter_xylosoxidans_uid205255',
#  '441768__Acholeplasma_laidlawii_PG_8A_uid58901',
#  '762376__Achromobacter_xylosoxidans_A8_uid59899',
#  '634458__Acetobacter_pasteurianus_IFO_3283_01_42C_uid158377',
#  '634459__Acetobacter_pasteurianus_IFO_3283_12_uid158379',
#  '634456__Acetobacter_pasteurianus_IFO_3283_26_uid158531',
#  '634453__Acetobacter_pasteurianus_IFO_3283_03_uid158373',
#  '329726__Acaryochloris_marina_MBIC11017_uid58167',
#  '634454__Acetobacter_pasteurianus_IFO_3283_07_uid158381',
#  '634452__Acetobacter_pasteurianus_IFO_3283_01_uid59279',
#  '574087__Acetohalobium_arabaticum_DSM_5501_uid51423',
#  '568816__Acidaminococcus_intestini_RyC_MR95_uid74445']

# %%
df = pd.read_pickle(os.path.join(path_4mer, "329726__Acaryochloris_marina_MBIC11017_uid58167.pd"))

# %%
df
# Out:
#                                       bacteria        fna   start  AAAA  AAAC  \
# 0      Acaryochloris_marina_MBIC11017_uid58167  NC_009925       0     4     3
# 1      Acaryochloris_marina_MBIC11017_uid58167  NC_009925     200     1     1
# 2      Acaryochloris_marina_MBIC11017_uid58167  NC_009925     400     2     2
# 3      Acaryochloris_marina_MBIC11017_uid58167  NC_009925     600     1     1
# 4      Acaryochloris_marina_MBIC11017_uid58167  NC_009925     800     0     0
# 5      Acaryochloris_marina_MBIC11017_uid58167  NC_009925    1000     0     0
# 6      Acaryochloris_marina_MBIC11017_uid58167  NC_009925    1200     0     0
# 7      Acaryochloris_marina_MBIC11017_uid58167  NC_009925    1400     1     0
# 8      Acaryochloris_marina_MBIC11017_uid58167  NC_009925    1600     1     1
# 9      Acaryochloris_marina_MBIC11017_uid58167  NC_009925    1800     1     0
# 10     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    2000     1     0
# 11     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    2200     2     2
# 12     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    2400     1     0
# 13     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    2600     0     1
# 14     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    2800     0     0
# 15     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    3000     0     0
# 16     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    3200     5     1
# 17     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    3400     0     1
# 18     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    3600     2     2
# 19     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    3800     1     1
# 20     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    4000     4     2
# 21     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    4200     1     1
# 22     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    4400     1     0
# 23     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    4600     0     0
# 24     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    4800     0     1
# 25     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    5000     1     1
# 26     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    5200     0     2
# 27     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    5400     0     1
# 28     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    5600     0     0
# 29     Acaryochloris_marina_MBIC11017_uid58167  NC_009925    5800     0     1
# ...                                        ...        ...     ...   ...   ...
# 41772  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  116600     5     1
# 41773  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  116800     1     3
# 41774  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  117000     1     0
# 41775  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  117200     2     1
# 41776  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  117400     3     0
# 41777  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  117600     3     3
# 41778  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  117800     0     1
# 41779  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  118000     2     1
# 41780  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  118200     2     0
# 41781  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  118400     0     2
# 41782  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  118600     1     0
# 41783  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  118800     0     0
# 41784  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  119000     1     0
# 41785  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  119200     0     1
# 41786  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  119400     1     1
# 41787  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  119600     0     0
# 41788  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  119800     1     1
# 41789  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  120000     0     1
# 41790  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  120200     2     1
# 41791  Acaryochloris_marina_MBIC11017_uid58167  NC_009933  120400     2     2
# 41792  Acaryochloris_marina_MBIC11017_uid58167  NC_009934       0     5     0
# 41793  Acaryochloris_marina_MBIC11017_uid58167  NC_009934     200     5     0
# 41794  Acaryochloris_marina_MBIC11017_uid58167  NC_009934     400     8     2
# 41795  Acaryochloris_marina_MBIC11017_uid58167  NC_009934     600     3     2
# 41796  Acaryochloris_marina_MBIC11017_uid58167  NC_009934     800     3     1
# 41797  Acaryochloris_marina_MBIC11017_uid58167  NC_009934    1000     2     2
# 41798  Acaryochloris_marina_MBIC11017_uid58167  NC_009934    1200     0     0
# 41799  Acaryochloris_marina_MBIC11017_uid58167  NC_009934    1400     0     2
# 41800  Acaryochloris_marina_MBIC11017_uid58167  NC_009934    1600     2     1
# 41801  Acaryochloris_marina_MBIC11017_uid58167  NC_009934    1800     0     2
#
#        AAAG  AAAT  AACA  AACC  AACG  ...  TTCG  TTCT  TTGA  TTGC  TTGG  TTGT  \
# 0         0     5     0     0     0  ...     0     2     0     2     0     0
# 1         2     2     1     1     0  ...     1     1     1     0     1     0
# 2         0     3     2     0     0  ...     0     1     1     0     0     1
# 3         1     2     2     1     0  ...     2     0     0     1     1     7
# 4         1     2     0     0     1  ...     2     0     1     0     2     0
# 5         0     1     0     0     0  ...     1     1     6     2     1     3
# 6         2     1     1     1     2  ...     0     1     2     2     3     0
# 7         1     1     0     1     1  ...     0     1     2     2     0     3
# 8         2     1     0     1     0  ...     0     1     0     2     1     2
# 9         3     2     0     0     0  ...     3     1     1     2     1     1
# 10        3     2     0     1     1  ...     1     3     1     0     0     0
# 11        1     0     1     0     2  ...     1     0     2     0     0     0
# 12        1     0     1     2     1  ...     0     0     1     2     4     0
# 13        0     0     1     2     0  ...     1     0     1     0     2     0
# 14        0     0     4     0     0  ...     0     0     0     2     2     0
# 15        0     1     0     1     0  ...     0     0     0     1     2     0
# 16        4     2     0     0     1  ...     0     1     2     3     2     0
# 17        1     1     0     0     1  ...     3     0     1     1     2     0
# 18        2     1     0     2     1  ...     1     0     2     1     1     0
# 19        0     0     1     0     0  ...     1     1     1     4     0     0
# 20        2     0     1     2     1  ...     2     2     0     2     0     0
# 21        1     0     1     1     2  ...     0     0     2     1     2     0
# 22        0     2     0     0     0  ...     0     0     2     2     2     0
# 23        0     0     0     1     1  ...     2     0     1     1     3     2
# 24        0     0     0     1     0  ...     0     0     2     1     1     1
# 25        0     2     0     1     0  ...     1     0     1     4     2     1
# 26        0     0     0     1     4  ...     0     0     1     0     1     1
# 27        0     0     0     2     1  ...     0     0     3     3     3     0
# 28        0     0     1     0     3  ...     2     0     0     1     1     3
# 29        0     0     0     0     2  ...     1     0     0     0     1     3
# ...     ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 41772     3     4     1     0     0  ...     0     0     2     0     1     0
# 41773     1     3     2     0     1  ...     1     2     2     3     0     1
# 41774     1     2     1     0     1  ...     0     0     3     2     0     1
# 41775     0     1     2     1     0  ...     0     0     1     3     0     1
# 41776     1     4     0     0     1  ...     1     2     1     0     1     1
# 41777     4     4     2     2     0  ...     0     1     1     0     1     0
# 41778     0     2     0     3     2  ...     1     0     0     0     1     0
# 41779     2     2     0     1     1  ...     0     1     3     0     2     1
# 41780     1     0     0     1     1  ...     1     2     1     1     1     1
# 41781     1     0     0     1     2  ...     2     1     1     0     4     2
# 41782     2     2     0     0     0  ...     0     3     1     1     0     1
# 41783     3     0     0     0     1  ...     0     1     2     3     0     0
# 41784     1     3     1     0     1  ...     1     4     1     1     2     2
# 41785     0     2     0     2     0  ...     1     0     6     1     0     1
# 41786     2     2     0     3     0  ...     2     1     2     3     1     2
# 41787     1     2     0     1     0  ...     1     0     2     1     2     1
# 41788     1     4     2     2     1  ...     0     0     2     2     1     1
# 41789     0     1     0     1     1  ...     0     1     2     0     1     1
# 41790     0     2     0     0     0  ...     1     1     3     0     1     0
# 41791     0     3     0     1     0  ...     0     0     1     0     1     0
# 41792     4     4     1     0     1  ...     1     1     3     1     1     1
# 41793     1     4     2     0     0  ...     0     3     1     1     1     0
# 41794     3     1     1     1     1  ...     0     0     1     1     0     1
# 41795     3     4     1     1     0  ...     0     2     0     1     0     2
# 41796     0     0     0     2     0  ...     0     0     2     0     2     2
# 41797     1     2     3     1     0  ...     0     2     2     1     3     0
# 41798     1     0     0     3     0  ...     1     2     0     0     2     2
# 41799     1     0     0     3     1  ...     0     3     1     1     0     1
# 41800     1     0     0     1     1  ...     1     1     1     2     0     1
# 41801     1     0     0     0     4  ...     2     1     2     1     2     0
#
#        TTTA  TTTC  TTTG  TTTT
# 0         4     3     0     2
# 1         2     0     0     1
# 2         1     1     0     0
# 3         0     0     0     0
# 4         2     0     2     2
# 5         1     2     1     4
# 6         1     1     2     1
# 7         1     0     2     3
# 8         3     3     3     3
# 9         0     2     4     2
# 10        0     1     0     0
# 11        2     0     1     3
# 12        0     0     2     2
# 13        2     0     2     3
# 14        3     1     1     0
# 15        0     1     1     1
# 16        2     0     2     0
# 17        1     1     1     1
# 18        1     0     3     0
# 19        1     0     2     1
# 20        4     2     0     3
# 21        1     0     2     1
# 22        0     1     1     3
# 23        3     1     5     3
# 24        3     1     1     0
# 25        0     2     2     1
# 26        1     0     2     1
# 27        1     0     3     2
# 28        1     0     3     0
# 29        0     0     1     0
# ...     ...   ...   ...   ...
# 41772     2     1     1     2
# 41773     0     1     3     2
# 41774     0     1     2     2
# 41775     1     2     1     1
# 41776     1     2     1     1
# 41777     2     0     2     1
# 41778     1     2     0     3
# 41779     0     0     1     0
# 41780     0     2     2     2
# 41781     1     1     2     1
# 41782     1     0     1     1
# 41783     2     1     2     2
# 41784     0     2     2     1
# 41785     0     2     2     4
# 41786     1     2     1     3
# 41787     2     1     1     5
# 41788     1     0     1     0
# 41789     0     3     0     1
# 41790     2     1     2     4
# 41791     1     1     2     2
# 41792     2     2     1     1
# 41793     2     1     0     3
# 41794     0     0     1     2
# 41795     7     3     1     9
# 41796     8     1     3     7
# 41797     1     0     2     0
# 41798     0     0     0     0
# 41799     1     4     1     1
# 41800     0     1     2     2
# 41801     1     1     1     2
#
# [41802 rows x 259 columns]

# %%
df.shape
# Out:
# (41802, 259)

# %%
df = pd.DataFrame(counts, index=names)

# %%
df

# %% [raw]
# df.to_pickle(os.path.join(path_4mer, "_Summary_4mers.pd"))

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
pca = PCA(n_components=20)
pca.fit(df)

# %%
plt.scatter(x=range(len(pca.explained_variance_ratio_)+1), 
            y=np.insert(pca.explained_variance_ratio_.cumsum(), 0, 0))
# plt.plot(pca.explained_variance_ratio_)
plt.show()
print(f"captured by PCA: {sum(pca.explained_variance_ratio_)*100:0.1f}%")

# %%
pca = PCA(n_components=2)
pca.fit(df)

# %%
t2 = pca.transform(df)

# %%
df_2 = pd.DataFrame(t2, index=names, columns=["pca_1", "pca_2"])

# %%
df_2

# %%
df_2.plot.scatter(x="pca_1", y="pca_2")
plt.show()

# %% [markdown]
# ## Machine Learning classification

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn import linear_model
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import ElasticNet
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
def scale_minmax(df, single_col=False):
    df = df + 1
    df = df.apply(np.log2)
    if single_col:
        return MinMaxScaler().fit_transform(df.values.reshape(-1, 1))
    else:
        return MinMaxScaler().fit_transform(df)

# %%
def error_and_corr(model, display=True, re_val=False):
    prediction = model.predict(X_test)
    pearson = np.corrcoef(prediction, y_test)[0, 1]
    mean_square_err = mean_squared_error(y_test, prediction)
    if re_val:
        return pearson, mean_square_err
    if display:
        print(f"Pearson correlation\t: *{pearson:.3f}*")
        print(f"Mean squared error\t: {mean_square_err:.3f}")
    return prediction

# %%
def some_predictions(pred):
    print("Expected values \t: " + "\t".join([f"{n:.2f}" for n in y_test[:10]]))
    print("Predicted values \t: " + "\t".join([f"{n:.2f}" for n in pred[:10]]))

# %%
X_train, X_test, y_train, y_test = train_test_split(df, ic50, test_size=0.1, random_state=0)

# %%
verbose = True

# %%
def linReg():
    if verbose:  print("Linear Regression")
    l_regr = linear_model.LinearRegression()
    l_regr.fit(X_train, y_train)
    return l_regr

# %%
l_regr = linReg()
pred = error_and_corr(l_regr)
some_predictions(pred)

# %%
def randForest():
    if verbose:  print("Random Forest Regression")
    rf_regr = RandomForestRegressor(max_depth=20, random_state=0, n_estimators=100, n_jobs=6)
    rf_regr.fit(X_train, y_train)
    return rf_regr

# %%
rf_regr = randForest()
rf_pred = error_and_corr(rf_regr)
some_predictions(rf_pred)

# %%
def svr():
    if verbose:  print("Support Vector Machine regression")
    svr_rbf = SVR(kernel='rbf', gamma='auto', cache_size=1000)
    svr_rbf.fit(X_train, y_train)
    return svr_rbf

# %%
svr_rbf = svr()
svr_pred = error_and_corr(svr_rbf)
some_predictions(svr_pred)

# %%
def k_neigh():
    if verbose:  print("K neighbours")
    neigh = KNeighborsRegressor(n_neighbors=20, n_jobs=6)
    neigh.fit(X_train, y_train)
    return neigh

# %%
neigh = k_neigh()
n_pred = error_and_corr(neigh)
some_predictions(n_pred)

# %%
def elas_net():
    if verbose:  print("Elastic Net")
    elastic_net = ElasticNet(l1_ratio=0.5, random_state=0)
    elastic_net.fit(X_train, y_train)
    return elastic_net

# %%
e_net = elas_net()
e_pred = error_and_corr(e_net)
some_predictions(e_pred)

# %%
def nn():
    if verbose:  print("Neural Network")
    nnm = MLPRegressor(hidden_layer_sizes=(100,100,), verbose=False, tol=0.000100)
    nnm.fit(X_train, y_train)
    return nnm

# %%
nn_m = nn()
nn_pred = error_and_corr(nn_m)
some_predictions(nn_pred)

# %%
models = [linReg, randForest, svr, k_neigh, elas_net, nn]

# %%
results = {}
for model in tqdm(models):
    print("******************************************")
    m = model()
    pred = error_and_corr(m)
    # some_predictions(pred)
    pearson, err = error_and_corr(m, re_val=True)
    results[model.__name__] = {"pearson": pearson, "err": err}

# %%
pred = error_and_corr(models[1](), display=False)

# %%
pd.DataFrame([pred, y_test.values])

# %%
from datetime import datetime
file_results = "results.csv"
file_results = osp.join(folder, file_results)

# %%
with open(file_results, "a") as f:
    f.write(str(datetime.now())[:16] + "," + str(param) + "," + "\n")
    f.write(",".join(results.keys()) + "\n")
    f.write(",".join([f"{v['pearson']:.3f}" for v in results.values()]) + "\n")
    f.write(",".join([f"{v['err']:.3f}" for v in results.values()]) + "\n")
    print(f"Results written in {file_results}")

# %% [markdown]
# ### End of the script.
# Sylvain @GIS

# %% [markdown]
# ## Keep other methods

# %%
def window(fseq, window_size=53):
    for i in range(len(fseq) - window_size + 1):
        yield fseq[i:i+window_size]

# %%
def kmer_pkl_path(k, fna_path):
    path_gbk = fna_path.replace(".fna", ".gbk")
    assert os.path.isfile(path_gbk), f"{fna_path} DOESN'T have a .gbk file ??"
    
    with open(path_gbk) as gbk:
        description=gbk.read()  #.replace('\n', '')
        
    identificator = 'db_xref="taxon:'
    taxo_start = description.find(identificator)
    taxo = description[taxo_start+len(identificator):
                       taxo_start+description[taxo_start:].find('"\n')]
    assert len(taxo) < 10, f"The taxo id search failed, found an id of length {len(taxo)}..."
    
    # TODO: ADD full path of the original file in the file name, or maybe in the .pkl
    
    return os.path.join(path_kmer_freq, str(k), taxo + ".pkl")

# %%
def kmer_freq_to_file(kmer_dic, freq_path):
    with open(freq_path, 'wb') as f_out:
        pickle.dump(kmer_dic, f_out)
